# %% [markdown]
# # Testing Agents

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Test_Chatbot_Functionality.ipynb

import os
from services.agents_service import AgentsService

from dotenv import load_dotenv 
load_dotenv()

# 1. Retrieve the key from the environment
active_key = os.getenv("GEMINI_API_KEY")
elevenlabs_key = os.getenv("ELEVENLABS_API_KEY")
tavily_key = os.getenv("TAVILY_API_KEY")

# 2. Check and print the key value
#print("--- API Keys Check Result ---")
#print(f"Gemini: {active_key}")
#print(f"ElevenLabs: {elevenlabs_key}")
#print("----------------------------")

# --- SETUP ---
# 1. Set your GEMINI_API_KEY environment variable.
#    Note: This is critical. The Gemini Client will fail to initialize without it.
# os.environ["GEMINI_API_KEY"] = "YOUR_SECRET_GEMINI_KEY"
# Out:
# Project root path: /Users/ferreira/Library/CloudStorage/GoogleDrive-klferreira28@gmail.com/My Drive/Data Science/Uni/3º ano/Fall/Capstone Project/Projeto/deNoise

# %%
# 2. Initialize the Agent (It automatically loads the Mock Database)
try:
    chatbot_agent = AgentsService(model="gemini-2.5-pro")
    print("✅ AgentsService Initialized (using CosmosDBServiceMOCK).")
except Exception as e:
    print(f"❌ Initialization Failed. Ensure GEMINI_API_KEY is set and all files are imported correctly: {e}")
    # Exit or handle error gracefully if initialization fails
    exit()
# Out:
# ✅ AgentsService Initialized (using CosmosDBServiceMOCK).

# %% [markdown]
# ## Conversational agent

# %%
chatbot_agent.generate_chat_answer(
    prompt="Any news on AI, last month?",
    user_id=""
)
# Out:
# [Condition(property='metadata.date', operator='$eq', value='2025-11-22'), Condition(property='metadata.date', operator='$eq', value='2025-11-23'), Condition(property='metadata.date', operator='$eq', value='2025-11-24'), Condition(property='metadata.date', operator='$eq', value='2025-11-25'), Condition(property='metadata.date', operator='$eq', value='2025-11-26'), Condition(property='metadata.date', operator='$eq', value='2025-11-27'), Condition(property='metadata.date', operator='$eq', value='2025-11-28'), Condition(property='metadata.date', operator='$eq', value='2025-11-29'), Condition(property='metadata.date', operator='$eq', value='2025-11-30'), Condition(property='metadata.date', operator='$eq', value='2025-12-01'), Condition(property='metadata.date', operator='$eq', value='2025-12-02'), Condition(property='metadata.date', operator='$eq', value='2025-12-03'), Condition(property='metadata.date', operator='$eq', value='2025-12-04'), Condition(property='metadata.date', operator='$eq', value='2025-12-05'), Condition(property='metadata.date', operator='$eq', value='2025-12-06'), Condition(property='metadata.date', operator='$eq', value='2025-12-07'), Condition(property='metadata.date', operator='$eq', value='2025-12-08'), Condition(property='metadata.date', operator='$eq', value='2025-12-09'), Condition(property='metadata.date', operator='$eq', value='2025-12-10'), Condition(property='metadata.date', operator='$eq', value='2025-12-11'), Condition(property='metadata.date', operator='$eq', value='2025-12-12'), Condition(property='metadata.date', operator='$eq', value='2025-12-13'), Condition(property='metadata.date', operator='$eq', value='2025-12-14'), Condition(property='metadata.date', operator='$eq', value='2025-12-15'), Condition(property='metadata.date', operator='$eq', value='2025-12-16'), Condition(property='metadata.date', operator='$eq', value='2025-12-17'), Condition(property='metadata.date', operator='$eq', value='2025-12-18'), Condition(property='metadata.date', operator='$eq', value='2025-12-19'), Condition(property='metadata.date', operator='$eq', value='2025-12-20'), Condition(property='metadata.date', operator='$eq', value='2025-12-21'), Condition(property='metadata.date', operator='$eq', value='2025-12-22')]
# Applying filters.
# conditions=[Condition(property='metadata.date', operator='$eq', value='2025-11-22'), Condition(property='metadata.date', operator='$eq', value='2025-11-23'), Condition(property='metadata.date', operator='$eq', value='2025-11-24'), Condition(property='metadata.date', operator='$eq', value='2025-11-25'), Condition(property='metadata.date', operator='$eq', value='2025-11-26'), Condition(property='metadata.date', operator='$eq', value='2025-11-27'), Condition(property='metadata.date', operator='$eq', value='2025-11-28'), Condition(property='metadata.date', operator='$eq', value='2025-11-29'), Condition(property='metadata.date', operator='$eq', value='2025-11-30'), Condition(property='metadata.date', operator='$eq', value='2025-12-01'), Condition(property='metadata.date', operator='$eq', value='2025-12-02'), Condition(property='metadata.date', operator='$eq', value='2025-12-03'), Condition(property='metadata.date', operator='$eq', value='2025-12-04'), Condition(property='metadata.date', operator='$eq', value='2025-12-05'), Condition(property='metadata.date', operator='$eq', value='2025-12-06'), Condition(property='metadata.date', operator='$eq', value='2025-12-07'), Condition(property='metadata.date', operator='$eq', value='2025-12-08'), Condition(property='metadata.date', operator='$eq', value='2025-12-09'), Condition(property='metadata.date', operator='$eq', value='2025-12-10'), Condition(property='metadata.date', operator='$eq', value='2025-12-11'), Condition(property='metadata.date', operator='$eq', value='2025-12-12'), Condition(property='metadata.date', operator='$eq', value='2025-12-13'), Condition(property='metadata.date', operator='$eq', value='2025-12-14'), Condition(property='metadata.date', operator='$eq', value='2025-12-15'), Condition(property='metadata.date', operator='$eq', value='2025-12-16'), Condition(property='metadata.date', operator='$eq', value='2025-12-17'), Condition(property='metadata.date', operator='$eq', value='2025-12-18'), Condition(property='metadata.date', operator='$eq', value='2025-12-19'), Condition(property='metadata.date', operator='$eq', value='2025-12-20'), Condition(property='metadata.date', operator='$eq', value='2025-12-21'), Condition(property='metadata.date', operator='$eq', value='2025-12-22')] logical_operator='$or'
# 'Based on the latest information, here are the key developments in AI from last month:\n\n*   **Advancements in AI Capabilities:** An AI hacking tool named Artemis, developed at Stanford, is demonstrating near-human capabilities. In a recent test, it outperformed 9 out of 10 professional penetration testers by finding security bugs at high speed, though it still has issues with false positives and occasionally misses obvious flaws.\n*   **Hiring Trends:** There\'s a noticeable shift in the job market within AI companies. These firms are hiring approximately one-third fewer Product Managers, indicating a potential change in team structures and priorities.\n*   **AI Adoption in Practice:** For engineering leaders, driving AI adoption is a significant focus. Real-world implementation is proving to be a complex task that requires a mix of deep domain knowledge, experience with AI tools, and solving traditional IT challenges. The choice of the right AI model is also a critical factor.\n*   **Hardware Accessibility:** High-end AI is becoming more accessible, with guides now available on how to build a personal desktop computer powerful enough to run large-parameter models (e.g., 235B-parameter models) from home.\n*   **Debate on AGI:** There is an ongoing critical discussion about the future of Artificial General Intelligence (AGI). Some argue that the current thinking around superintelligence is flawed and amplified within an "echo chamber," particularly in the Bay Area, calling for more realistic and critical thought to shape the future of AI.'

# %%
chatbot_agent.generate_chat_answer(
    prompt="Can you repeat what you've said about InnovateCo?",
    user_id="General Enthusiast"
)
# Out:
# 'Of course. Here is the information I shared about InnovateCo:\n\nInnovateCo recently raised **$150 million in a Series C funding round**. They plan to use this new investment to expand their market presence in Europe.'

# %%
chatbot_agent.generate_chat_answer(
    prompt="What was my first question?",
    user_id="General Enthusiast"
)
# Out:
# "As deNoise, an AI assistant focused on the startup ecosystem, I don't have access to our previous conversation history. My purpose is to provide you with the latest information on startups, funding rounds, and market trends.\n\nHow can I help you with that today?"

# %%
chatbot_agent.clear_session_memory(
    user_id="General Enthusiast"
)
# Out:
# {'status': 'success', 'message': 'Chat history cleared'}

# %%
chatbot_agent.generate_chat_answer(
    prompt="Startup News on: eco.sapo.pt",
    user_id="General Enthusiast"
)
# Out:
# 'Based on the latest from ECO Sapo, Portugal\'s startup ecosystem is showing strong momentum and exciting developments:\n\n*   **Top Performers:** The "Technology Fast 50 Portugal" ranking highlighted **Bloq.it, i-charging, and Coverflex** as the top three fastest-growing tech companies, showcasing their sustained and rapid expansion.\n*   **Ecosystem Growth:** The national startup scene has reached a new milestone, now counting over **5,000 active ventures**. This represents an 8% increase from the previous year, with these companies employing around 28,000 people and generating approximately €2.8 billion in revenue.\n*   **Fintech Leadership Change:** In a significant move, fintech company **Rauva** announced a leadership change, with co-founder Jon Fath stepping down as CEO.\n*   **Global Expansion:** Portuguese AI specialist **Starkdata** has opened a new office in Virginia, USA, marking a strategic push into the American market.\n*   **Green Tech Investment:** A Porto-based startup successfully secured **€11 million** to develop innovative electric boats designed to reduce energy consumption by up to 80%, signaling strong investor confidence in sustainable maritime technology.\n*   **New Acceleration Program:** Startup Portugal has launched the **“Scale Up Now”** program, which will accelerate five selected startups through the prestigious Plug and Play accelerator in San Francisco.'

# %%
chatbot_agent.generate_chat_answer(
    prompt="Specific Startup News on empreendedor.com",
    user_id="General Enthusiast"
)
# Out:
# 'Based on the latest news from empreendedor.com, here are the key highlights from the Portuguese startup scene:\n\n*   **Ecosystem Growth:** Portugal\'s startup ecosystem has seen impressive growth, expanding by 16% in 2024 to a total of 4,719 registered startups, solidifying its position as a vibrant hub for new ventures.\n*   **Major Acquisition:** The Swedish group Allurity has successfully acquired the Portuguese firm CloudComputing, a strategic move to strengthen its presence in the Southern European cloud-computing market.\n*   **Founder Insights:** In a recent interview, a startup founder shared a powerful lesson on resilience, stating that "adapting is the only way to survive" in the face of market shifts.\n*   **Prestigious Award:** Startup Lisboa has announced the six finalists for the "João Vasconcelos – Empreendedor do Ano" award. The winner will be revealed on September 30th.\n*   **Global Trends:** A 2024 global report highlighted the major forces shaping the startup world, including increased economic pressures, a slowdown in financing, and the transformative influence of AI.\n*   **Local Initiatives:** To boost the local entrepreneurial scene, Startup Leiria organized an "Ignition Week" aimed at supporting and accelerating new ventures in the region.'

# %%
chatbot_agent.generate_chat_answer(
    prompt="I need to know the latest funding rounds and policy changes announced this month.",
    user_id="Hub_Manager"
)
# Out:
# MOCK SERVICE INITIALIZED: Using hardcoded test data.
# 'Based on the latest information from this month, here are the key updates on funding and policy:\n\n**Funding and Acquisitions:**\n\n*   **InnovateCo** raised a significant **$150M Series C round** last week to fund its European expansion.\n*   In a strategic acquisition, **GlobalTech** acquired competitor **QuickFix for $50M** to secure talent and intellectual property.\n\n**Policy Changes:**\n\n*   The Portuguese government has introduced a new policy offering **tax incentives for early-stage green technology startups**, which is now in effect.\n\n**Regional Ecosystem Insights:**\n\n*   **Talent:** A recent market report highlights a growing **talent shortage in Lisbon**, with a 30% increase in demand for AI engineers over the last quarter.\n*   **Porto:** A new venture studio, **Alpha Studio**, has launched in Porto. It will focus on building B2B SaaS companies and aims to incubate five startups within the next year.'

# %%
chatbot_agent.generate_chat_answer(
    prompt="I need to know the latest funding rounds and policy changes announced yesterday?.",
    user_id="Hub_Manager"
)
# Out:
# MOCK SERVICE INITIALIZED: Using hardcoded test data.
# "Based on the latest updates, here are the key highlights:\n\n*   **Policy Change**: A new Portuguese government policy is now in effect, offering tax incentives for early-stage startups that are focused on green technology.\n*   **Major Funding Round**: The startup 'InnovateCo' raised $150M in a Series C round last week to fund its European expansion.\n*   **Acquisition**: In a strategic move, 'GlobalTech' has acquired its competitor 'QuickFix' for $50M to secure talent and intellectual property."

# %%
chatbot_agent.generate_chat_answer(
    prompt="what is the custom user profile you are using?",
    user_id="hub_manager"
)
# Out:
# 'My custom user profile is focused on regional development in Portugal, specifically for the Lisbon and Porto areas, with an emphasis on policy. I am configured to highlight talent reports and local investment activity in my responses.'

# %% [markdown]
# ## Report agent

# %%
chatbot_agent.generate_report(
    topics= "Big Tech international News",
    time_range= "monthly",
    structure= "include a small introduction, NO key takeaways and a final conclusion in CAPS LOCK",
    user_id= "a2xmZXJyZWlyYTI4QGdt"
)
# Out:
# [Condition(property='metadata.date', operator='$eq', value='2025-11-22'), Condition(property='metadata.date', operator='$eq', value='2025-11-23'), Condition(property='metadata.date', operator='$eq', value='2025-11-24'), Condition(property='metadata.date', operator='$eq', value='2025-11-25'), Condition(property='metadata.date', operator='$eq', value='2025-11-26'), Condition(property='metadata.date', operator='$eq', value='2025-11-27'), Condition(property='metadata.date', operator='$eq', value='2025-11-28'), Condition(property='metadata.date', operator='$eq', value='2025-11-29'), Condition(property='metadata.date', operator='$eq', value='2025-11-30'), Condition(property='metadata.date', operator='$eq', value='2025-12-01'), Condition(property='metadata.date', operator='$eq', value='2025-12-02'), Condition(property='metadata.date', operator='$eq', value='2025-12-03'), Condition(property='metadata.date', operator='$eq', value='2025-12-04'), Condition(property='metadata.date', operator='$eq', value='2025-12-05'), Condition(property='metadata.date', operator='$eq', value='2025-12-06'), Condition(property='metadata.date', operator='$eq', value='2025-12-07'), Condition(property='metadata.date', operator='$eq', value='2025-12-08'), Condition(property='metadata.date', operator='$eq', value='2025-12-09'), Condition(property='metadata.date', operator='$eq', value='2025-12-10'), Condition(property='metadata.date', operator='$eq', value='2025-12-11'), Condition(property='metadata.date', operator='$eq', value='2025-12-12'), Condition(property='metadata.date', operator='$eq', value='2025-12-13'), Condition(property='metadata.date', operator='$eq', value='2025-12-14'), Condition(property='metadata.date', operator='$eq', value='2025-12-15'), Condition(property='metadata.date', operator='$eq', value='2025-12-16'), Condition(property='metadata.date', operator='$eq', value='2025-12-17'), Condition(property='metadata.date', operator='$eq', value='2025-12-18'), Condition(property='metadata.date', operator='$eq', value='2025-12-19'), Condition(property='metadata.date', operator='$eq', value='2025-12-20'), Condition(property='metadata.date', operator='$eq', value='2025-12-21'), Condition(property='metadata.date', operator='$eq', value='2025-12-22')]
# Applying filters.
# conditions=[Condition(property='metadata.date', operator='$eq', value='2025-11-22'), Condition(property='metadata.date', operator='$eq', value='2025-11-23'), Condition(property='metadata.date', operator='$eq', value='2025-11-24'), Condition(property='metadata.date', operator='$eq', value='2025-11-25'), Condition(property='metadata.date', operator='$eq', value='2025-11-26'), Condition(property='metadata.date', operator='$eq', value='2025-11-27'), Condition(property='metadata.date', operator='$eq', value='2025-11-28'), Condition(property='metadata.date', operator='$eq', value='2025-11-29'), Condition(property='metadata.date', operator='$eq', value='2025-11-30'), Condition(property='metadata.date', operator='$eq', value='2025-12-01'), Condition(property='metadata.date', operator='$eq', value='2025-12-02'), Condition(property='metadata.date', operator='$eq', value='2025-12-03'), Condition(property='metadata.date', operator='$eq', value='2025-12-04'), Condition(property='metadata.date', operator='$eq', value='2025-12-05'), Condition(property='metadata.date', operator='$eq', value='2025-12-06'), Condition(property='metadata.date', operator='$eq', value='2025-12-07'), Condition(property='metadata.date', operator='$eq', value='2025-12-08'), Condition(property='metadata.date', operator='$eq', value='2025-12-09'), Condition(property='metadata.date', operator='$eq', value='2025-12-10'), Condition(property='metadata.date', operator='$eq', value='2025-12-11'), Condition(property='metadata.date', operator='$eq', value='2025-12-12'), Condition(property='metadata.date', operator='$eq', value='2025-12-13'), Condition(property='metadata.date', operator='$eq', value='2025-12-14'), Condition(property='metadata.date', operator='$eq', value='2025-12-15'), Condition(property='metadata.date', operator='$eq', value='2025-12-16'), Condition(property='metadata.date', operator='$eq', value='2025-12-17'), Condition(property='metadata.date', operator='$eq', value='2025-12-18'), Condition(property='metadata.date', operator='$eq', value='2025-12-19'), Condition(property='metadata.date', operator='$eq', value='2025-12-20'), Condition(property='metadata.date', operator='$eq', value='2025-12-21'), Condition(property='metadata.date', operator='$eq', value='2025-12-22')] logical_operator='$or'
# RAG CONTEXT: ARTICLE 1:
# The New York Times - Breaking News, US News, World News and...
# Wordle
#
# The Crossword
#
# Pips NEW
#
# ###
#
# Strands
#
# Connections
#
# Sudoku
#
# Letter Boxed
#
# Tiles
#
# ### Community
#
# ### Newsletters
#
# Gameplay Logo
#
# Puzzles, brain teasers, solving tips and more.
#
# Easy Mode Logo
#
# Get an easy version of one of the hardest crossword puzzles of the week.
#
# ### Cooking
#
# Recipes, advice and inspiration for everyday cooking, special occasions and more.
#
# ### Recipes
#
# ### Editors' Picks
#
# ### Newsletters
#
# The Cooking Newsletter Logo [...] Word games, logic puzzles and crosswords, including an extensive archive.
#
# ### Play
#
# Spelling Bee
#
# The Mini Crossword
#
# Wordle
#
# The Crossword
#
# Pips NEW
#
# ###
#
# Strands
#
# Connections
#
# Sudoku
#
# Letter Boxed
#
# Tiles
#
# ### Community
#
# ### Newsletters
#
# Gameplay Logo
#
# Puzzles, brain teasers, solving tips and more.
#
# Easy Mode Logo
#
# Get an easy version of one of the hardest crossword puzzles of the week.
#
# ### Cooking
#
# Recipes, advice and inspiration for everyday cooking, special occasions and more. [...] Cannonball with Wesley Morris Logo
#
# Come on in, the culture's fine.
#
# The Headlines Logo
#
# Your morning listen. Top stories, in 10 minutes.
#
# Serial: The Retrievals
# Season 2 Logo
#
# An investigation into
# C-sections.
#
# ### Newsletters
#
# Audio Logo
#
# Our editors share their favorite listens from The Times and beyond.
#
# Serial Logo
#
# Be the first to know about our new shows.
#
# ### Games
#
# Word games, logic puzzles and crosswords, including an extensive archive.
#
# ### Play
#
# Spelling Bee
#
# The Mini Crossword
#
# ARTICLE 2:
# Breaking News, Latest News and Videos | CNN
# ## Inside politics [...] ## Climate
#
# iceland-lupine-flowers-instagram-creators-digvid.jpg
# UW.00_59_42_08.Still001.jpg
# Kendeda 3.jpg
#
# ## Paid Content
#
# ## More from CNN
#
# ## goodbye 2025, Hello 2026
#
# A & A NYE thumb 1.png
# 115608_PantoneColorMOS_16x9_clean.00_00_01_02.Still001.jpg
# still_22181232_2976370_still.jpg
#
# ## Art and Style [...] ## CNN Underscored
#
# ## BEST-IN-CLASS
#
# LEAD-ellen cashmere sweater 1.jpg
#
# ## Expert-Backed Guides
#
# A small air pump on asphalt in front of a car tire.
#
# ## Editors' picks
#
# darn-tough-the-standard-cnnu.jpg
#
# ## World
#
# thumb_22215929_944791.498_thumb.jpg
# clipped thumbnail - russian-general-car-bomb-digivid-intldsk - CNN ID 22220883 - 00:00:11;03
# Bondi Beach shooting
#
# ## Brown University shooting
#
# ARTICLE 3:
# CBS News | Breaking news, top stories & today's latest headlines
# NASA continues to aim its space telescopes at the visiting ice ball, estimated to be up to 3.5 miles in size.
#
# ### Latest Galleries
#
# All In The Family
#
# #### Notable Deaths in 2025
#
# A look back at the esteemed personalities who've left us this year, who'd touched us with their innovation, creativity and humanity.
#
# Christy Martin
#
# #### The life & near death of prizefighter Christy Salters-Martin
#
# Christy Salters-Martin dominated in the boxing ring but faced her toughest challenger at home. [...] Rep. Ro Khanna said the release of an initial tranche of files and photos related to late sex offender Jeffrey Epstein was a "slap in the face of survivors," while Rep. Thomas Massie said the DOJ is "flouting the spirit and the letter of the law."
#
# ### HealthWatch
#
#
#
# #### HealthWatch
#
# #### Flu cases surging nationwide [...] US-POLITICS-TURNING POINT-KIRK
#
# #### Erika Kirk endorses JD Vance for president
#
# Turning Point USA CEO Erika Kirk endorsed Vice President JD Vance for president in 2028 at the organization's annual youth conference.
#
# ### Managing Your Money
#
# gettyimages-2235662644.jpg
#
# #### How much interest will a $25,000 CD account earn in 2026?
#
# Interest earnings on a CD account of this size can still be significant, and it won't take too long to earn, either.
#
# gettyimages-2038081306.jpg
#
# ARTICLE 4:
# Latest News: Breaking Headlines and Video on Today's Top Stories
# Morning Rundown: Marco Rubio and Steve Witkoff clash on diplomacy, U.S. pursues third vessel off Venezuela, and child bride turned bodybuilding champion
#
# ### Sections
#
# ### Local
#
# ### tv
#
# ### Featured
#
# ### More From NBC
#
# ### Follow NBC News
#
# news Alerts
#
# There are no new alerts at this time
#
# # Latest Stories
#
# Breaking news from around the world.
#
# Netanyahu Says He Nominated Trump For Nobel Peace Prize [...] Tokyo Electric Power Company's Kashiwazaki Kariwa nuclear power plant stands along the seaside in Kashiwazaki, Japan
# Tokyo Electric Power Company's Kashiwazaki Kariwa nuclear power plant stands along the seaside in Kashiwazaki, Japan
#
# ## Asia
#
# ## Asia
#
# ## Passenger bus crash in Indonesia kills at least 16 people, official says
#
# Indonesia Bus Crash
# Indonesia Bus Crash
#
# ## War in Ukraine
#
# ## War in Ukraine
#
# ## Russian general killed by bomb under his car in Moscow [...] Aaron Rodgers of the Pittsburgh Steelers and Jared Goff of the Detroit Lions meet after the Steelers beat the Lions 29-24.
#
# Aaron Rodgers of the Pittsburgh Steelers and Jared Goff of the Detroit Lions meet after the Steelers beat the Lions 29-24.
#
# ## War in Ukraine
#
# ## War in Ukraine
#
# ## U.S. envoy Steve Witkoff calls Ukraine, Russia talks productive
#
# Image: RUSSIA-UKRAINE-CONFLICT-US-DIPLOMACY
# Image: RUSSIA-UKRAINE-CONFLICT-US-DIPLOMACY
#
# © 2025 NBCUniversal Media, LLC
#
# ARTICLE 5:
# News
# Lisbon, 2 July 2025 – Portugal Ventures, the venture capital company of Grupo Português do Fomento, announces the reinforcement of its investment in INEYE ...Read more
# "## Introduction\n\nHello investors and innovators! What a whirlwind of a year 2025 is turning out to be! While the global stage is buzzing with major geopolitical developments, from productive diplomatic talks between Russia and Ukraine led by U.S. envoy Steve Witkoff to the shocking news of a Russian general being killed by a car bomb in Moscow, it's absolutely critical to find the signals of growth that shine through the noise!\n\nAnd we've found a fantastic one for you! Straight from Europe's vibrant tech hub, a major investment move was just made! On **July 2, 2025**, the brilliant team at **Portugal Ventures**, the venture capital powerhouse of Grupo Português do Fomento, announced they are doubling down and **reinforcing their investment in the exciting company INEYE**! This move, announced in Lisbon, is a powerful testament to the resilience and incredible opportunity bubbling up in the European startup scene, even amidst global uncertainty! This is where the action is!\n\n## CONCLUSION\n\nAMIDST A COMPLEX GLOBAL LANDSCAPE DOMINATED BY GEOPOLITICAL HEADLINES, THE EUROPEAN VENTURE CAPITAL ECOSYSTEM IS DEMONSTRATING INCREDIBLE STRENGTH AND FORWARD MOMENTUM! THE FOLLOW-ON INVESTMENT BY PORTUGAL VENTURES INTO INEYE IS A LOUD AND CLEAR SIGNAL THAT INNOVATION AND GROWTH ARE THRIVING! FOR INVESTORS AND STARTUP MANAGERS, THE MESSAGE IS SIMPLE: FOCUS ON THESE FUNDAMENTAL STORIES OF VALUE CREATION, BECAUSE THAT IS WHERE THE REAL OPPORTUNITY LIES! LET'S GO"

# %% [markdown]
# ## Podcast agent

# %%
chatbot_agent.generate_podcast(
    topics="Any recent positive news and success stories",
    time_range="weekly",
    structure="Extremely casual tone with A LOT of humor. Strucure: Start with the conclusion, followed by key highlights, and end with a brief introduction.",
    user_id="a2xmZXJyZWlyYTI4QGdt"
)
# Out:
# /Users/ferreira/Library/CloudStorage/GoogleDrive-klferreira28@gmail.com/My Drive/Data Science/Uni/3º ano/Fall/Capstone Project/Projeto/deNoise/services/cosmos_db_service.py:212: LangChainDeprecationWarning: The class `AzureCosmosDBNoSqlVectorSearch` was deprecated in LangChain 0.3.22 and will be removed in 1.0. An updated version of the class exists in the `langchain-azure-ai package and should be used instead. To use it run `pip install -U `langchain-azure-ai` and import as `from `langchain_azure_ai.vectorstores import AzureCosmosDBNoSqlVectorSearch``.
#   vector_search = AzureCosmosDBNoSqlVectorSearch(
# 'So the big takeaway is... move to Portugal! Seriously! Forget Silicon Valley, it\'s all about Lisbon now! The venture capital is flowing and the success stories are piling up! Go learn Portuguese, people!\n\nOkay, for real, here’s the scoop! On July 2nd, Portugal Ventures announced they\'re pumping even MORE cash into a company called INEYE! HUGE! Plus, the whole country is a hotspot! People are literally googling "Top 10 Scaleups to Watch" and "Burning Heroes Startup Awards" for Portugal! It\'s on fire!\n\nAlright, welcome back to The deNoised Signal! After wading through a sea of depressing headlines, I finally found some good news for you! And it\'s a banger'
